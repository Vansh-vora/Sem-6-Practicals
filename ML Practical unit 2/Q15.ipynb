# %%
#
#Create a scatter plot for the following data
#1. house_size = [1000, 1500, 2000, 2500, 3000] house_price = [200000, 250000, 
#300000, 350000,
#400000]
#2. actual_prices = [200000, 250000, 300000, 350000, 400000] predicted_prices = 
#[210000, 245000,
#290000, 360000, 390000]

# %%
import matplotlib.pyplot as plt

# Data
house_size = [1000, 1500, 2000, 2500, 3000]
house_price = [200000, 250000, 300000, 350000, 400000]

# Plot
plt.scatter(house_size, house_price)

# Labels and title
plt.xlabel("House Size (sq ft)")
plt.ylabel("House Price")
plt.title("House Size vs Price")

plt.grid()
plt.show()
