# %%
#Write machine learning code to Compute the correlation matrix and visualize it as a
#heatmap.  
#Dataset:
# Feature_1 = [10, 20, 30, 40, 50]
# Feature_2 = [15, 25, 35, 45, 55]
# Feature_3 = [5, 10, 15, 20, 25]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data={
    'Feature_1':[10,20,30,40,50],
    'Feature_2':[15,25,35,45,55],
    'Feature_3':[5,10,15,20,25]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    Feature_1  Feature_2  Feature_3
# 0         10         15          5
# 1         20         25         10
# 2         30         35         15
# 3         40         45         20
# 4         50         55         25

# %%
corr_matrix=df.corr()
print(corr_matrix)
# Out:
#            Feature_1  Feature_2  Feature_3
# Feature_1        1.0        1.0        1.0
# Feature_2        1.0        1.0        1.0
# Feature_3        1.0        1.0        1.0

# %%
plt.imshow(corr_matrix)

plt.xticks(range(len(corr_matrix.columns)),corr_matrix.columns)
plt.yticks(range(len(corr_matrix.columns)),corr_matrix.columns)

plt.colorbar()

plt.title("Correlation Matrix Heatmap")
plt.show()
