# %%
#Create a box plot for the dataset [1, 3, 5, 7, 9, 15, 20, 25] and find the outliers.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data=[1,3,5,7,9,15,20,25]

# %%
plt.boxplot(data)
plt.title("Box Plot")
plt.ylabel("Values")
plt.show()

# %%
Q1=np.percentile(data,25)
Q3=np.percentile(data,75)
IQR=Q3-Q1

lower_bound=Q1-1.5 *IQR
upper_bound=Q3+1.5 *IQR

outliers=[x for x in data if x < lower_bound or x > upper_bound]

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
print("Outliers:", outliers)
# Out:
# Q1: 4.5
# Q3: 16.25
# IQR: 11.75
# Lower Bound: -13.125
# Upper Bound: 33.875
# Outliers: []
