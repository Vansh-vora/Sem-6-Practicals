# %%
#Write a machine learning code to visualize the frequency of each fruit category in a 
#bar chart.
#dataset {'Fruits': ['Apple', 'Banana', 'Orange', 'Apple', 'Banana', 'Banana', 'Orange', 
#'Apple']}

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data={
    'Fruits': ['Apple','Banana','Orange','Apple','Banana','Banana','Orange','Apple']
}
df=pd.DataFrame(data)
print(df)
# Out:
#    Fruits
# 0   Apple
# 1  Banana
# 2  Orange
# 3   Apple
# 4  Banana
# 5  Banana
# 6  Orange
# 7   Apple

# %%
frequency=df['Fruits'].value_counts()

# %%
plt.bar(frequency.index,frequency.values,edgecolor='red')
plt.xlabel("Fruits")
plt.ylabel("Frequency")
plt.title("Frequency of Fruits")
plt.show()
