# %%
#
#models = ['Logistic Regression', 'SVM', 'Random Forest'] training_times = [2.1, 
#12.5, 8.4]
#Create a bar graph with following conditions:
# Graph color should be gree
# It should be horizontal graph

# %%
import matplotlib.pyplot as plt

# %%
models=['Logistic Regresstion','SVM','Random Forest']
training=[2.1,12.5,8.4]

# %%
plt.bar(models,training,color='green')
plt.xlabel("Training Time")
plt.ylabel("Models")
plt.title("Model Training Time Comparison")
plt.show()
